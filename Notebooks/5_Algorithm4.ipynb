# %% [markdown]
# #### This code serves to test Algorithm 4 for the Iterative Domain Information Framework

# %%
import glob as glob
import math, random
import pandas as pd
from DatasetNames import get_dataset_class_name
from ExtraFunctions import *

from MultiClassPrediction import MultiClassPrediction
from SingleClassPrediction import SingleClassPrediction
from MultiClassDescription import MultiClassDescription

from MultiClassPredictionByText import MultiClassPredictionByText
from SingleClassPredictionByText import SingleClassPredictionByText

# %%
DATASET_NAME = "PathMNIST"
NUMBER_OF_IMAGES = 3 # Total number of images to be used
NUMBER_OF_AUGMENTATIONS = 2 # Number of augmentations to be used
number_of_experiment = 1 # Number of experiment to be conducted

source_directory = f"../Datasets/{DATASET_NAME}/test"  # Change this to your test directory path
_, image_paths = get_balanced_random_images(source_directory, n = NUMBER_OF_IMAGES)

random.seed(55)
random.shuffle(image_paths)
initial_image_paths = image_paths.copy()

dataset_classes_of_interest = get_dataset_class_name(DATASET_NAME)
init_classes_of_interest = list(dataset_classes_of_interest.values())

classes_of_interest_list = [random.sample(init_classes_of_interest, len(init_classes_of_interest)) for i in range(len(image_paths))]

multiclass_image_tasks = create_multiclass_augmented_image_tasks(image_paths, classes_of_interest_list, number_of_classes_to_predict=len(init_classes_of_interest), total_number_of_augmentations=NUMBER_OF_AUGMENTATIONS)

# %% [markdown]
# #### Playground

# %%
model_list = [
    #     {
    #     "model_name": "claude-3-5-sonnet-20241022",
    #     "model_type": "claude",
    # },
    # {
    #     "model_name": "gpt-4o",
    #     "model_type": "openai",
    # },
    {
        "model_name": "gpt-4o-mini",
        "model_type": "openai",
    }
]

# %%
mc_descriptor = MultiClassDescription(batch_size = 1, max_workers=4)
txt_based_classifier = MultiClassPredictionByText(batch_size = 1, max_workers=4)
txt_based_single_class_classifier = SingleClassPredictionByText(batch_size = 1, max_workers=4)

# %%
exp_results = []

for experiment in range(number_of_experiment):
    print(f"Experiment {experiment+1}/{number_of_experiment}")

    # Iterate over the models
    for model in model_list:
        model_name = model["model_name"]
        model_type = model["model_type"]

        print(f"Model: {model_name}")
        print(f"Model Type: {model_type}")

        multiclass_image_tasks = create_multiclass_augmented_image_tasks(image_paths, classes_of_interest_list, number_of_classes_to_predict=len(init_classes_of_interest), total_number_of_augmentations=NUMBER_OF_AUGMENTATIONS)

        mc_descriptor.update_model(model_name)
        txt_based_classifier.update_model(model_name)
        txt_based_single_class_classifier.update_model(model_name)

        # For each model, initialize the variables for the Algorithm
        n = len(init_classes_of_interest)
        k = 2
        threshold = 2
        number_of_classes_to_predict = math.ceil(n / k)
        image_paths = initial_image_paths
        voting_result_list = None    

        # Get the descriptions of the images
        rs = mc_descriptor.process_images(multiclass_image_tasks, model_type=model_type)   

        # Create Multiclass Image Tasks from the descriptions
        multiclass_image_tasks = []
        for item in rs['images']:
            image_path = item['image_path']
            classes_to_use = random.sample(init_classes_of_interest, len(init_classes_of_interest))

            # Combine all the descriptions into one so that it can be seen as a single medical report and also add headings to each section
            combined_description = f"Technical Quality: {item['technical_quality']}\nAnatomical Description: {item['anatomical_description']}\nFindings: {item['findings']}"
            
            task = MultiClassImageTask(image_path=image_path, classes=classes_to_use)
            task.set_image_textual_description(combined_description)
            n = len(init_classes_of_interest)
            k = 2
            task.set_num_predictions(number_of_classes_to_predict)
            multiclass_image_tasks.append(task)

        while number_of_classes_to_predict >= threshold:

            # Prompt the model to predict "number_of_classes_to_predict" classes for each image
            rs = txt_based_classifier.process_descriptions(multiclass_image_tasks, model_type=model_type)

            # Set the predicted classes as the new classes of interest
            result_list, image_paths, classes_of_interest_list = extract_image_classes_from_multiclass_predictions(rs, number_of_classes_to_predict)

            print("Image Paths: ", image_paths)
            print("Image Paths: ", len(image_paths))

            log_experiment_results(dataset_classes_of_interest, exp_results, experiment, model_name, model_type, number_of_classes_to_predict, image_paths, classes_of_interest_list)

            # Update the number of classes to predict
            number_of_classes_to_predict = math.ceil(number_of_classes_to_predict / k)

            multiclass_image_tasks = create_new_multitask_image_tasks(number_of_classes_to_predict, result_list)

        if rs:
            # Result from Multiclass Prediction
            result_list, _, _ = extract_image_classes_from_multiclass_predictions(rs)

            # Merge augmentation results
            result_list, voting_result_list = transform_result_list_to_single_image_tasks(result_list)
        else:
            # Go to SingleTask result list directly
            result_list = create_singleclass_image_tasks(image_paths, classes_of_interest_list)

        # Predict the single classes for each image
        f_res = txt_based_single_class_classifier.process_descriptions(result_list, model_type)
        correct_classes, pred_classes, image_paths = extract_single_classes(f_res, dataset_classes_of_interest)

        log_experiment_results(dataset_classes_of_interest, exp_results, experiment, model_name, model_type, number_of_classes_to_predict, image_paths, pred_classes, voting_result_list)
# Out:
# Experiment 1/1
# Model: gpt-4o
# Model Type: openai
# Inside process Descriptions for MultiClassPredictionByText:  [[MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\7\\image_2935.png', classes=['debris', 'mucus', 'normal colon mucosa', 'smooth muscle', 'cancer-associated stroma', 'background', 'adipose', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], num_predictions=5, encoded_image=None, features=None, image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Variable cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_353.png', classes=['cancer-associated stroma', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'mucus', 'normal colon mucosa', 'background', 'debris', 'lymphocytes', 'adipose'], num_predictions=5, encoded_image=None, features=None, image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'Moderate resolution with some color artifacts'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Moderate cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining with color artifacts', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_5183.png', classes=['lymphocytes', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'debris', 'background', 'mucus', 'cancer-associated stroma', 'normal colon mucosa'], num_predictions=5, encoded_image=None, features=None, image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Low cellular density', 'internal_architecture': 'Predominantly fibrous components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Parallel alignment', 'relationship_to_landmarks': 'Cells aligned within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Uniform staining', 'texture': 'Smooth fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\0\\image_1897.png', classes=['colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'background', 'adipose', 'lymphocytes', 'debris', 'cancer-associated stroma', 'normal colon mucosa'], num_predictions=5, encoded_image=None, features=None, image_textual_description="Technica ...
# Image Paths:  ['../Datasets/PathMNIST/test\\7\\image_2935.png', '../Datasets/PathMNIST/test\\5\\image_353.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\8\\image_1754.png', '../Datasets/PathMNIST/test\\2\\image_2461.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\2\\image_5355.png', '../Datasets/PathMNIST/test\\0\\image_2150.png', '../Datasets/PathMNIST/test\\4\\image_4782.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\6\\image_6718.png', '../Datasets/PathMNIST/test\\6\\image_6813.png', '../Datasets/PathMNIST/test\\6\\image_834.png', '../Datasets/PathMNIST/test\\8\\image_4370.png', '../Datasets/PathMNIST/test\\5\\image_1733.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\2\\image_3212.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\3\\image_1969.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\4\\image_1905.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\0\\image_887.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\8\\image_4445.png', '../Datasets/PathMNIST/test\\7\\image_638.png', '../Datasets/PathMNIST/test\\3\\image_457.png', '../Datasets/PathMNIST/test\\5\\image_5966.png', '../Datasets/PathMNIST/test\\0\\image_2401.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\7\\image_5856.png', '../Datasets/PathMNIST/test\\8\\image_3272.png', '../Datasets/PathMNIST/test\\5\\image_1985.png', '../Datasets/PathMNIST/test\\5\\image_3485.png', '../Datasets/PathMNIST/test\\4\\image_6904.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\1\\image_5089.png', '../Datasets/PathMNIST/test\\6\\image_702.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\0\\image_3423.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\1\\image_1228.png', '../Datasets/PathMNIST/test\\0\\image_5185.png', '../Datasets/PathMNIST/test\\2\\image_842.png', '../Datasets/PathMNIST/test\\1\\image_2821.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\4\\image_562.png', '../Datasets/PathMNIST/test\\3\\image_4995.png', '../Datasets/PathMNIST/test\\2\\image_5067.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\3\\image_4616.png', '../Datasets/PathMNIST/test\\5\\image_4007.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\8\\image_4382.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\5\\image_2833.png', '../Datasets/PathMNIST/test\\0\\image_6827.png', '../Datasets/PathMNIST/test\\1\\image_5852.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\2\\image_3844.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\7\\image_4363.png', '../Datasets/PathMNIST/test\\6\\image_2578.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\7\\image_2633.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\7\\image_279.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\4\\image_3490.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\2\\image_6713.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\ ...
# Image Paths:  200
# Predicted Classes of Interest: [['normal colon mucosa', 'background', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma'], ['smooth muscle', 'background', 'cancer-associated stroma', 'lymphocytes', 'debris'], ['cancer-associated stroma', 'normal colon mucosa', 'background', 'debris', 'smooth muscle'], ['background', 'smooth muscle', 'adipose', 'debris', 'lymphocytes'], ['background', 'lymphocytes', 'cancer-associated stroma', 'debris', 'smooth muscle'], ['background', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'debris'], ['background', 'smooth muscle', 'mucus', 'lymphocytes', 'normal colon mucosa'], ['cancer-associated stroma', 'debris', 'background', 'smooth muscle', 'mucus'], ['normal colon mucosa', 'smooth muscle', 'lymphocytes', 'background', 'mucus'], ['debris', 'background', 'smooth muscle', 'mucus', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma', 'background', 'smooth muscle', 'debris'], ['background', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'debris', 'lymphocytes'], ['cancer-associated stroma', 'background', 'debris', 'normal colon mucosa', 'mucus'], ['background', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'debris'], ['mucus', 'cancer-associated stroma', 'debris', 'normal colon mucosa', 'background'], ['smooth muscle', 'lymphocytes', 'debris', 'background', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'cancer-associated stroma', 'smooth muscle', 'background'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'mucus', 'background'], ['lymphocytes', 'cancer-associated stroma', 'debris', 'background', 'smooth muscle'], ['debris', 'smooth muscle', 'background', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris', 'background', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus', 'background'], ['lymphocytes', 'background', 'cancer-associated stroma', 'debris', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'background', 'debris', 'lymphocytes', 'mucus'], ['lymphocytes', 'cancer-associated stroma', 'background', 'debris', 'colorectal adenocarcinoma epithelium'], ['debris', 'normal colon mucosa', 'smooth muscle', 'background', 'cancer-associated stroma'], ['background', 'lymphocytes', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'debris', 'mucus', 'background', 'smooth muscle'], ['lymphocytes', 'normal colon mucosa', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'background'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma', 'debris', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'debris', 'background'], ['debris', 'background', 'lymphocytes', 'normal colon mucosa', 'smooth muscle'], ['background', 'debris', 'mucus', 'cancer-associated stroma', 'smooth muscle'], ['adipose', 'cancer-associated stroma', 'background', 'mucus', 'debris'], ['background', 'cancer-associated stroma', 'normal colon mucosa', 'debris', 'mucus'], ['debris', 'background', 'smooth muscle', 'cancer-associated stroma', 'normal colon mucosa'], ['colorectal adenocarcinoma epithelium', 'debris', 'lymphocytes', 'cancer-associated stroma', 'background'], ['cancer-associated stroma', 'background', 'debris', 'smooth muscle', 'normal colon mucosa'], ['background', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'smooth muscle'], ['smooth muscle', 'cancer-associated stroma', 'debris', 'background', 'normal colon mucosa'], ['background', 'cancer-associated stroma', 'debris', 'smooth muscle', 'mucus'], ['mucus', 'background', 'debris', 'smooth muscle', 'cancer-associated stroma'], ['mucus', 'background', 'normal colon mucosa', 'colorectal adenocarcinoma e ...
# Correct Classes: ['cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'adipose', 'debris', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'mucus', 'normal colon mucosa', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'mucus', 'cancer-associated stroma', 'background', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'adipose', 'background', 'adipose', 'debris', 'background', 'mucus', 'mucus', 'lymphocytes', 'debris', 'mucus', 'normal colon mucosa', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'adipose', 'background', 'cancer-associated stroma', 'debris', 'smooth muscle', 'cancer-associated stroma', 'normal colon mucosa', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'lymphocytes', 'mucus', 'adipose', 'debris', 'lymphocytes', 'adipose', 'smooth muscle', 'background', 'debris', 'debris', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'normal colon mucosa', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'lymphocytes', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'adipose', 'adipose', 'lymphocytes', 'smooth muscle', 'background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'smooth muscle', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'smooth muscle', 'normal colon mucosa', 'background', 'background', 'colorectal adenocarcinoma epithelium', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'mucus', 'cancer-associated stroma', 'debris', 'adipose', 'mucus', 'lymphocytes', 'cancer-associated stroma', 'debris', 'adipose', 'background', 'lymphocytes', 'lymphocytes', 'adipose', 'mucus', 'mucus', 'mucus', 'background', 'background', 'cancer-associated stroma', 'mucus', 'lymphocytes', 'normal colon mucosa', 'debris', 'debris', 'adipose', 'smooth muscle', 'mucus', 'debris', 'lymphocytes', 'smooth muscle', 'background', 'background', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'debris', 'background', 'smooth muscle', 'adipose', 'cancer-associated stroma', 'background', 'smooth muscle', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'debris', 'background', 'lymphocytes', 'background', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'normal colon mucosa', 'smooth muscle', 'smooth muscle', 'normal colon mucosa', 'debris', 'smooth muscle', 'adipose', 'background', 'cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium']
# Accuracy: 148 out of 200
# Inside process Descriptions for MultiClassPredictionByText:  [[MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\7\\image_2935.png', classes=['normal colon mucosa', 'background', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma'], num_predictions=3, encoded_image=None, features=['Elongated spindle-shaped cells', 'Cellular components', 'Clear cellular detail', 'Fibrous stroma', 'Interwoven pattern', 'Fibrous texture', 'Indistinct margins', 'High resolution'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Variable cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_353.png', classes=['smooth muscle', 'background', 'cancer-associated stroma', 'lymphocytes', 'debris'], num_predictions=3, encoded_image=None, features=['Moderate resolution', 'Elongated spindle-shaped cells', 'Moderate cellular density', 'Color artifacts', 'Fibrous stroma', 'Interwoven pattern', 'Fibrous texture', 'Cellular components'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'Moderate resolution with some color artifacts'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Moderate cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining with color artifacts', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_5183.png', classes=['cancer-associated stroma', 'normal colon mucosa', 'background', 'debris', 'smooth muscle'], num_predictions=3, encoded_image=None, features=['Smooth texture', 'Fibrous components', 'Cellular components', 'Fibrous stroma', 'Low cellular density', 'Parallel alignment', 'High resolution', 'Spindle-shaped cells', 'Uniform staining'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Low cellular density', 'internal_architecture': 'Predominantly fibrous components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Parallel alignment', 'relationship_to_landmarks': 'Cells aligned within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Uniform staining', 'texture': 'Smooth fibrous texture'}}"), MultiClassImageTask(image_p ...
# Image Paths:  ['../Datasets/PathMNIST/test\\7\\image_2935.png', '../Datasets/PathMNIST/test\\5\\image_353.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\8\\image_1754.png', '../Datasets/PathMNIST/test\\2\\image_2461.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\2\\image_5355.png', '../Datasets/PathMNIST/test\\0\\image_2150.png', '../Datasets/PathMNIST/test\\4\\image_4782.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\6\\image_6718.png', '../Datasets/PathMNIST/test\\6\\image_6813.png', '../Datasets/PathMNIST/test\\6\\image_834.png', '../Datasets/PathMNIST/test\\8\\image_4370.png', '../Datasets/PathMNIST/test\\5\\image_1733.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\2\\image_3212.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\3\\image_1969.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\4\\image_1905.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\0\\image_887.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\8\\image_4445.png', '../Datasets/PathMNIST/test\\7\\image_638.png', '../Datasets/PathMNIST/test\\3\\image_457.png', '../Datasets/PathMNIST/test\\5\\image_5966.png', '../Datasets/PathMNIST/test\\0\\image_2401.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\1\\image_5089.png', '../Datasets/PathMNIST/test\\6\\image_702.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\0\\image_3423.png', '../Datasets/PathMNIST/test\\7\\image_5856.png', '../Datasets/PathMNIST/test\\8\\image_3272.png', '../Datasets/PathMNIST/test\\5\\image_1985.png', '../Datasets/PathMNIST/test\\5\\image_3485.png', '../Datasets/PathMNIST/test\\4\\image_6904.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\1\\image_1228.png', '../Datasets/PathMNIST/test\\0\\image_5185.png', '../Datasets/PathMNIST/test\\2\\image_842.png', '../Datasets/PathMNIST/test\\1\\image_2821.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\4\\image_562.png', '../Datasets/PathMNIST/test\\3\\image_4995.png', '../Datasets/PathMNIST/test\\2\\image_5067.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\3\\image_4616.png', '../Datasets/PathMNIST/test\\5\\image_4007.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\8\\image_4382.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\5\\image_2833.png', '../Datasets/PathMNIST/test\\0\\image_6827.png', '../Datasets/PathMNIST/test\\1\\image_5852.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\2\\image_3844.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\7\\image_4363.png', '../Datasets/PathMNIST/test\\6\\image_2578.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\7\\image_2633.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\7\\image_279.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\4\\image_3490.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\2\\image_6713.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\ ...
# Image Paths:  200
# Predicted Classes of Interest: [['background', 'smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris', 'background'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['background', 'smooth muscle', 'adipose'], ['cancer-associated stroma', 'debris', 'background'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'background'], ['debris', 'cancer-associated stroma', 'background'], ['lymphocytes', 'normal colon mucosa', 'background'], ['background', 'debris', 'cancer-associated stroma'], ['background', 'cancer-associated stroma', 'debris'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background'], ['normal colon mucosa', 'mucus', 'background'], ['background', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['mucus', 'background', 'normal colon mucosa'], ['background', 'debris', 'cancer-associated stroma'], ['smooth muscle', 'background', 'cancer-associated stroma'], ['mucus', 'background', 'normal colon mucosa'], ['cancer-associated stroma', 'debris', 'background'], ['debris', 'cancer-associated stroma', 'background'], ['background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background'], ['background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'debris', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background'], ['background', 'cancer-associated stroma', 'smooth muscle'], ['background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'debris', 'background'], ['background', 'lymphocytes', 'normal colon mucosa'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'background'], ['smooth muscle', 'cancer-associated stroma', 'background'], ['cancer-associated stroma', 'debris', 'background'], ['mucus', 'cancer-associated stroma', 'background'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['background', 'cancer-associated stroma', 'mucus'], ['colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'background'], ['cancer-associated stroma', 'background', 'colorectal adenocarcinoma epithelium'], ['mucus', 'background', 'adipose'], ['debris', 'background', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['debris', 'cancer-associated stroma', 'background'], ['background', 'debris', 'cancer-associated stroma'], ['background', 'cancer-associated stroma', 'debris'], ['background', 'debris', 'cancer-associated stroma'], ['background', 'smooth muscle', 'normal colon mucosa'], ['cancer-associated stroma', 'background', 'debris'], ['background', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['normal colon mucosa', 'background', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['cancer-associated stroma', 'smooth muscle', 'background'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'background'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'cancer-associated stroma', 'normal colon mucosa'], ['background', 'lymphocytes', 'debris'], ['background', 'cancer-associated stroma', 'smooth muscle'], ['background', 'normal colon mucosa', 'cancer-associated stroma'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'background'], ['smooth muscle', 'cancer-associated stroma', 'background'], ...
# Correct Classes: ['cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'adipose', 'debris', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'mucus', 'normal colon mucosa', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'mucus', 'adipose', 'background', 'adipose', 'debris', 'background', 'mucus', 'mucus', 'lymphocytes', 'debris', 'mucus', 'normal colon mucosa', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'adipose', 'background', 'cancer-associated stroma', 'debris', 'smooth muscle', 'cancer-associated stroma', 'normal colon mucosa', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'lymphocytes', 'mucus', 'adipose', 'debris', 'lymphocytes', 'adipose', 'smooth muscle', 'background', 'debris', 'debris', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'normal colon mucosa', 'lymphocytes', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'adipose', 'adipose', 'lymphocytes', 'smooth muscle', 'background', 'cancer-associated stroma', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'smooth muscle', 'smooth muscle', 'normal colon mucosa', 'background', 'background', 'colorectal adenocarcinoma epithelium', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'mucus', 'cancer-associated stroma', 'debris', 'adipose', 'mucus', 'lymphocytes', 'cancer-associated stroma', 'debris', 'adipose', 'background', 'lymphocytes', 'lymphocytes', 'adipose', 'mucus', 'mucus', 'mucus', 'background', 'background', 'cancer-associated stroma', 'mucus', 'lymphocytes', 'normal colon mucosa', 'debris', 'debris', 'adipose', 'smooth muscle', 'background', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'debris', 'mucus', 'debris', 'lymphocytes', 'smooth muscle', 'background', 'background', 'smooth muscle', 'adipose', 'cancer-associated stroma', 'background', 'smooth muscle', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'debris', 'background', 'lymphocytes', 'background', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'normal colon mucosa', 'smooth muscle', 'smooth muscle', 'normal colon mucosa', 'debris', 'smooth muscle', 'adipose', 'background', 'cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium']
# Accuracy: 114 out of 200
# Inside process Descriptions for MultiClassPredictionByText:  [[MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\7\\image_2935.png', classes=['background', 'smooth muscle', 'cancer-associated stroma'], num_predictions=2, encoded_image=None, features=['Fibrous and cellular components', 'Elongated spindle-shaped cells', 'Cells interspersed within fibrous stroma', 'Interwoven pattern', 'Variable cellular density', 'Indistinct margins', 'Spindle-shaped cells', 'Heterogeneous staining'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Variable cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_353.png', classes=['cancer-associated stroma', 'debris', 'background'], num_predictions=2, encoded_image=None, features=['Moderate cellular density', 'Color artifacts', 'Fibrous stroma', 'Interwoven pattern', 'Heterogeneous staining with color artifacts', 'Indistinct margins', 'Spindle-shaped cells'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'Moderate resolution with some color artifacts'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Moderate cellular density', 'internal_architecture': 'Fibrous and cellular components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Interwoven pattern', 'relationship_to_landmarks': 'Cells interspersed within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Heterogeneous staining with color artifacts', 'texture': 'Fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\5\\image_5183.png', classes=['background', 'smooth muscle', 'cancer-associated stroma'], num_predictions=2, encoded_image=None, features=['Smooth fibrous texture', 'Fibrous components', 'Fibrous stroma', 'Low cellular density', 'Parallel alignment', 'Spindle-shaped cells', 'Uniform staining'], image_textual_description="Technical Quality: {'image_modality': 'Histological image', 'positioning': 'Standard histological section', 'image_quality': 'High resolution with clear cellular detail'}\nAnatomical Description: {'location': 'Tissue section', 'anatomical_landmarks': ['Cell nuclei', 'Fibrous stroma'], 'orientation': 'Transverse plane'}\nFindings: {'composition': {'density_characteristics': 'Low cellular density', 'internal_architecture': 'Predominantly fibrous components'}, 'morphology': {'shape': 'Elongated spindle-shaped cells', 'margins': 'Indistinct', 'size': 'Cells approximately 20-30 micrometers in length'}, 'distribution': {'spatial_arrangement': 'Parallel alignment', 'relationship_to_landmarks': 'Cells aligned within fibrous stroma'}, 'signal_characteristics': {'intensity_patterns': 'Uniform staining', 'texture': 'Smooth fibrous texture'}}"), MultiClassImageTask(image_path='../Datasets/PathMNIST/test\\0\\image_1897.png', classes=['background', 'smooth muscl ...
# Image Paths:  ['../Datasets/PathMNIST/test\\7\\image_2935.png', '../Datasets/PathMNIST/test\\5\\image_353.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\8\\image_1754.png', '../Datasets/PathMNIST/test\\2\\image_2461.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\2\\image_5355.png', '../Datasets/PathMNIST/test\\0\\image_2150.png', '../Datasets/PathMNIST/test\\4\\image_4782.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\6\\image_6718.png', '../Datasets/PathMNIST/test\\6\\image_6813.png', '../Datasets/PathMNIST/test\\6\\image_834.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\3\\image_1969.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\8\\image_4370.png', '../Datasets/PathMNIST/test\\5\\image_1733.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\2\\image_3212.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\4\\image_1905.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\0\\image_887.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\8\\image_4445.png', '../Datasets/PathMNIST/test\\7\\image_638.png', '../Datasets/PathMNIST/test\\3\\image_457.png', '../Datasets/PathMNIST/test\\5\\image_5966.png', '../Datasets/PathMNIST/test\\0\\image_2401.png', '../Datasets/PathMNIST/test\\8\\image_3449.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\1\\image_5089.png', '../Datasets/PathMNIST/test\\6\\image_702.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\0\\image_3423.png', '../Datasets/PathMNIST/test\\7\\image_5856.png', '../Datasets/PathMNIST/test\\8\\image_3272.png', '../Datasets/PathMNIST/test\\5\\image_1985.png', '../Datasets/PathMNIST/test\\5\\image_3485.png', '../Datasets/PathMNIST/test\\4\\image_6904.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\1\\image_1228.png', '../Datasets/PathMNIST/test\\0\\image_5185.png', '../Datasets/PathMNIST/test\\2\\image_842.png', '../Datasets/PathMNIST/test\\1\\image_2821.png', '../Datasets/PathMNIST/test\\6\\image_163.png', '../Datasets/PathMNIST/test\\3\\image_4616.png', '../Datasets/PathMNIST/test\\5\\image_4007.png', '../Datasets/PathMNIST/test\\6\\image_2955.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\4\\image_562.png', '../Datasets/PathMNIST/test\\3\\image_4995.png', '../Datasets/PathMNIST/test\\2\\image_5067.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\2\\image_3844.png', '../Datasets/PathMNIST/test\\5\\image_5183.png', '../Datasets/PathMNIST/test\\7\\image_4363.png', '../Datasets/PathMNIST/test\\6\\image_2578.png', '../Datasets/PathMNIST/test\\8\\image_4382.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\5\\image_2833.png', '../Datasets/PathMNIST/test\\0\\image_6827.png', '../Datasets/PathMNIST/test\\1\\image_5852.png', '../Datasets/PathMNIST/test\\3\\image_3983.png', '../Datasets/PathMNIST/test\\7\\image_2633.png', '../Datasets/PathMNIST/test\\7\\image_6687.png', '../Datasets/PathMNIST/test\\7\\image_279.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\3\\image_4775.png', '../Datasets/PathMNIST/test\\4\\image_3490.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\2\\image_6713.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\0\\image_1897.png', '../Datasets/PathMNIST/test\\ ...
# Image Paths:  200
# Predicted Classes of Interest: [['cancer-associated stroma', 'smooth muscle'], ['cancer-associated stroma', 'background'], ['background', 'smooth muscle'], ['adipose', 'background'], ['cancer-associated stroma', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['normal colon mucosa', 'lymphocytes'], ['cancer-associated stroma', 'background'], ['normal colon mucosa', 'lymphocytes'], ['background', 'cancer-associated stroma'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['normal colon mucosa', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'background'], ['colorectal adenocarcinoma epithelium', 'background'], ['cancer-associated stroma', 'debris'], ['smooth muscle', 'background'], ['normal colon mucosa', 'background'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['debris', 'background'], ['background', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'normal colon mucosa'], ['smooth muscle', 'cancer-associated stroma'], ['background', 'cancer-associated stroma'], ['mucus', 'cancer-associated stroma'], ['smooth muscle', 'cancer-associated stroma'], ['mucus', 'background'], ['background', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['adipose', 'background'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'background'], ['cancer-associated stroma', 'background'], ['cancer-associated stroma', 'background'], ['normal colon mucosa', 'background'], ['cancer-associated stroma', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['normal colon mucosa', 'background'], ['normal colon mucosa', 'background'], ['lymphocytes', 'background'], ['cancer-associated stroma', 'background'], ['background', 'normal colon mucosa'], ['background', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['background', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'background'], ['cancer-associated stroma', 'background'], ['cancer-associated stroma', 'background'], ['background', 'smooth muscle'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'smooth muscle'], ['cancer-associated stroma', 'background'], ['colorectal adenocarcinoma epithelium', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa'], ['smooth muscle', 'cancer-associated stroma'], ['background', 'mucus'], ['normal colon mucosa', 'lymphocytes'], ['background', 'lymphocytes'], ['cancer-associated stroma', 'background'], ['cancer-associated stroma', 'debris'], ['cancer-associated stroma', 'background'], ['background', 'adipose'], ['normal colon mucosa', 'lymphocytes'], ['background', 'cancer-associated stroma'], ['background', 'adipose'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma'], ['background', 'adipose'], ['background', 'smooth muscle'], ['debris', 'background'], ['lymphocytes', 'background'], ['background', 'normal colon mucosa'], ['background', 'cancer-associated stroma'], ['debris', 'background'], ['colorectal adenocarcinoma epithelium', 'background'], ['cancer- ...
# Correct Classes: ['cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'adipose', 'debris', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'mucus', 'normal colon mucosa', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'mucus', 'adipose', 'background', 'adipose', 'debris', 'background', 'normal colon mucosa', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'mucus', 'mucus', 'mucus', 'lymphocytes', 'debris', 'mucus', 'cancer-associated stroma', 'debris', 'smooth muscle', 'cancer-associated stroma', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'adipose', 'background', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'lymphocytes', 'mucus', 'adipose', 'debris', 'lymphocytes', 'adipose', 'smooth muscle', 'background', 'debris', 'debris', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'normal colon mucosa', 'lymphocytes', 'adipose', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'adipose', 'adipose', 'lymphocytes', 'smooth muscle', 'background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'smooth muscle', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'smooth muscle', 'normal colon mucosa', 'background', 'background', 'colorectal adenocarcinoma epithelium', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'mucus', 'cancer-associated stroma', 'debris', 'adipose', 'background', 'lymphocytes', 'cancer-associated stroma', 'debris', 'adipose', 'mucus', 'lymphocytes', 'lymphocytes', 'adipose', 'mucus', 'mucus', 'mucus', 'background', 'background', 'cancer-associated stroma', 'mucus', 'lymphocytes', 'normal colon mucosa', 'debris', 'debris', 'adipose', 'smooth muscle', 'background', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'debris', 'mucus', 'debris', 'lymphocytes', 'smooth muscle', 'background', 'background', 'smooth muscle', 'adipose', 'cancer-associated stroma', 'background', 'smooth muscle', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'debris', 'background', 'lymphocytes', 'background', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'normal colon mucosa', 'adipose', 'background', 'cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'normal colon mucosa', 'debris', 'smooth muscle', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium']
# Accuracy: 95 out of 200
# ...
# Image Paths:  ['../Datasets/PathMNIST/test\\8\\image_1288.png', '../Datasets/PathMNIST/test\\8\\image_1754.png', '../Datasets/PathMNIST/test\\6\\image_702.png', '../Datasets/PathMNIST/test\\2\\image_6417.png', '../Datasets/PathMNIST/test\\5\\image_353.png', '../Datasets/PathMNIST/test\\7\\image_3832.png', '../Datasets/PathMNIST/test\\2\\image_6713.png', '../Datasets/PathMNIST/test\\6\\image_6511.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\7\\image_5856.png', '../Datasets/PathMNIST/test\\7\\image_638.png', '../Datasets/PathMNIST/test\\2\\image_3212.png', '../Datasets/PathMNIST/test\\1\\image_5521.png', '../Datasets/PathMNIST/test\\0\\image_5185.png', '../Datasets/PathMNIST/test\\5\\image_5004.png', '../Datasets/PathMNIST/test\\4\\image_4782.png', '../Datasets/PathMNIST/test\\2\\image_114.png', '../Datasets/PathMNIST/test\\6\\image_2578.png', '../Datasets/PathMNIST/test\\2\\image_5067.png', '../Datasets/PathMNIST/test\\7\\image_279.png', '../Datasets/PathMNIST/test\\7\\image_4939.png', '../Datasets/PathMNIST/test\\1\\image_5852.png', '../Datasets/PathMNIST/test\\8\\image_3272.png', '../Datasets/PathMNIST/test\\4\\image_562.png', '../Datasets/PathMNIST/test\\1\\image_1253.png', '../Datasets/PathMNIST/test\\3\\image_2637.png', '../Datasets/PathMNIST/test\\0\\image_887.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\4\\image_2621.png', '../Datasets/PathMNIST/test\\8\\image_4382.png', '../Datasets/PathMNIST/test\\5\\image_5053.png', '../Datasets/PathMNIST/test\\4\\image_1905.png', '../Datasets/PathMNIST/test\\3\\image_3284.png', '../Datasets/PathMNIST/test\\4\\image_1905.png', '../Datasets/PathMNIST/test\\7\\image_279.png', '../Datasets/PathMNIST/test\\4\\image_4285.png', '../Datasets/PathMNIST/test\\0\\image_6358.png', '../Datasets/PathMNIST/test\\7\\image_4939.png', '../Datasets/PathMNIST/test\\0\\image_1240.png', '../Datasets/PathMNIST/test\\5\\image_4007.png', '../Datasets/PathMNIST/test\\2\\image_5355.png', '../Datasets/PathMNIST/test\\8\\image_1566.png', '../Datasets/PathMNIST/test\\4\\image_1537.png', '../Datasets/PathMNIST/test\\4\\image_6904.png', '../Datasets/PathMNIST/test\\8\\image_7038.png', '../Datasets/PathMNIST/test\\3\\image_2057.png', '../Datasets/PathMNIST/test\\0\\image_3756.png', '../Datasets/PathMNIST/test\\7\\image_2633.png', '../Datasets/PathMNIST/test\\1\\image_5089.png', '../Datasets/PathMNIST/test\\3\\image_4995.png', '../Datasets/PathMNIST/test\\8\\image_1288.png', '../Datasets/PathMNIST/test\\6\\image_834.png', '../Datasets/PathMNIST/test\\8\\image_3272.png', '../Datasets/PathMNIST/test\\4\\image_1596.png', '../Datasets/PathMNIST/test\\0\\image_2150.png', '../Datasets/PathMNIST/test\\4\\image_5881.png', '../Datasets/PathMNIST/test\\5\\image_5966.png', '../Datasets/PathMNIST/test\\5\\image_4007.png', '../Datasets/PathMNIST/test\\3\\image_840.png', '../Datasets/PathMNIST/test\\7\\image_2633.png', '../Datasets/PathMNIST/test\\5\\image_5966.png', '../Datasets/PathMNIST/test\\7\\image_2194.png', '../Datasets/PathMNIST/test\\8\\image_1566.png', '../Datasets/PathMNIST/test\\8\\image_1754.png', '../Datasets/PathMNIST/test\\2\\image_842.png', '../Datasets/PathMNIST/test\\4\\image_6904.png', '../Datasets/PathMNIST/test\\0\\image_5185.png', '../Datasets/PathMNIST/test\\4\\image_1596.png', '../Datasets/PathMNIST/test\\1\\image_2657.png', '../Datasets/PathMNIST/test\\5\\image_4135.png', '../Datasets/PathMNIST/test\\1\\image_1228.png', '../Datasets/PathMNIST/test\\6\\image_6718.png', '../Datasets/PathMNIST/test\\0\\image_3210.png', '../Datasets/PathMNIST/test\\6\\image_4176.png', '../Datasets/PathMNIST/test\\3\\image_4616.png', '../Datasets/PathMNIST/test\\5\\image_4135.png', '../Datasets/PathMNIST/test\\3\\image_4616.png', '../Datasets/PathMNIST/test\\6\\image_3431.png', '../Datasets/PathMNIST/test\\2\\image_6713.png', '../Datasets/PathMNIST/test\\5\\image_1985.png', '../Datasets/PathMNIST/test\\4\\image_1537.png', '../Datasets/PathMNIST/test ...
# Image Paths:  200
# Predicted Classes of Interest: [['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'cancer-associated stroma'], ['normal colon mucosa', 'smooth muscle'], ['debris', 'cancer-associated stroma'], ['cancer-associated stroma', 'mucus'], ['cancer-associated stroma', 'normal colon mucosa'], ['debris', 'cancer-associated stroma'], ['mucus', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'debris'], ['smooth muscle', 'background'], ['adipose', 'background'], ['mucus', 'normal colon mucosa'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'background'], ['background', 'lymphocytes'], ['normal colon mucosa', 'background'], ['debris', 'cancer-associated stroma'], ['background', 'smooth muscle'], ['cancer-associated stroma', 'smooth muscle'], ['debris', 'colorectal adenocarcinoma epithelium'], ['mucus', 'normal colon mucosa'], ['smooth muscle', 'background'], ['debris', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'cancer-associated stroma'], ['background', 'adipose'], ['smooth muscle', 'cancer-associated stroma'], ['mucus', 'normal colon mucosa'], ['background', 'smooth muscle'], ['debris', 'cancer-associated stroma'], ['lymphocytes', 'background'], ['smooth muscle', 'cancer-associated stroma'], ['normal colon mucosa', 'smooth muscle'], ['debris', 'cancer-associated stroma'], ['smooth muscle', 'normal colon mucosa'], ['background', 'cancer-associated stroma'], ['cancer-associated stroma', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes'], ['mucus', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'background'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'normal colon mucosa'], ['background', 'lymphocytes'], ['background', 'smooth muscle'], ['smooth muscle', 'debris'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'adipose'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'background'], ['debris', 'colorectal adenocarcinoma epithelium'], ['background', 'cancer-associated stroma'], ['adipose', 'background'], ['cancer-associated stroma', 'smooth muscle'], ['normal colon mucosa', 'smooth muscle'], ['cancer-associated stroma', 'lymphocytes'], ['background', 'lymphocytes'], ['normal colon mucosa', 'mucus'], ['cancer-associated stroma', 'normal colon mucosa'], ['debris', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris'], ['normal colon mucosa', 'background'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['adipose', 'background'], ['lymphocytes', 'cancer-associated stroma'], ['normal colon mucosa', 'mucus'], ['adipose', 'background'], ['colorectal adenocarcinoma epithelium', 'smooth muscle'], ['cancer-associated stroma', 'background'], ['smooth muscle', 'normal colon mucosa'], ['lymphocytes', 'cancer-associated stroma'], ['debris', 'normal colon mucosa'], ['cancer-associated stroma', 'debris'], ['smooth muscle', 'background'], ['normal colon mucosa', 'smooth muscle'], ['debris', 'cancer-associated stroma'], ['adipose', 'cancer-associated stroma'], ['mucus', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'smooth muscle'], ['normal colon mucosa', 'cancer-associated stroma'], ['background', 'smooth muscle'], ['smooth muscle', 'debris'], ['background', 'adipose'], ['normal colon mucosa', 'cancer-associated stroma'], ['background', 'smooth muscle'], ['cancer-associated stroma', 'debris'], ['background', 'smooth muscle'], ['adipose', 'background'], ['lymphocytes', 'cancer-associated stroma'], [ ...
# Correct Classes: ['colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'debris', 'smooth muscle', 'cancer-associated stroma', 'debris', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'cancer-associated stroma', 'debris', 'background', 'adipose', 'smooth muscle', 'mucus', 'debris', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'cancer-associated stroma', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'lymphocytes', 'adipose', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'lymphocytes', 'mucus', 'cancer-associated stroma', 'mucus', 'adipose', 'cancer-associated stroma', 'adipose', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'mucus', 'mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'adipose', 'cancer-associated stroma', 'background', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus', 'adipose', 'mucus', 'smooth muscle', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'debris', 'mucus', 'adipose', 'mucus', 'background', 'smooth muscle', 'background', 'normal colon mucosa', 'adipose', 'normal colon mucosa', 'lymphocytes', 'smooth muscle', 'lymphocytes', 'normal colon mucosa', 'debris', 'smooth muscle', 'mucus', 'smooth muscle', 'adipose', 'adipose', 'background', 'mucus', 'debris', 'cancer-associated stroma', 'debris', 'adipose', 'smooth muscle', 'background', 'smooth muscle', 'adipose', 'lymphocytes', 'debris', 'cancer-associated stroma', 'smooth muscle', 'normal colon mucosa', 'adipose', 'lymphocytes', 'normal colon mucosa', 'adipose', 'lymphocytes', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'adipose', 'smooth muscle', 'background', 'debris', 'adipose', 'debris', 'colorectal adenocarcinoma epithelium', 'debris', 'debris', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'cancer-associated stroma', 'debris', 'background', 'cancer-associated stroma', 'adipose', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'background', 'background', 'cancer-associated stroma', 'background', 'normal colon mucosa', 'adipose', 'adipose', 'lymphocytes', 'lymphocytes', 'debris', 'lymphocytes', 'normal colon mucosa', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'lymphocytes', 'lymphocytes', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'background', 'lymphocytes', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'lymphocytes', 'cancer-associated stroma', 'mucus', 'debris', 'background', 'normal colon mucosa', 'smooth muscle', 'mucus', 'cancer-associated stroma', 'normal colon mucosa', 'debris', 'background', 'lymphocytes', 'adipose', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'background', 'mucus', 'mucus', 'mucus', 'background', 'cancer-associated stroma', 'background', 'lymphocytes', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'adipose', 'normal colon mucosa', 'lymphocytes', 'smooth muscle', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'lymphocytes', 'adipose', 'mucus', 'smooth muscle']
# Accuracy: 82 out of 200
# Predicted Classes of Interest: ['cancer-associated stroma', 'debris', 'mucus', 'cancer-associated stroma', 'smooth muscle', 'cancer-associated stroma', 'cancer-associated stroma', 'smooth muscle', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'smooth muscle', 'adipose', 'normal colon mucosa', 'cancer-associated stroma', 'cancer-associated stroma', 'lymphocytes', 'normal colon mucosa', 'cancer-associated stroma', 'background', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'smooth muscle', 'cancer-associated stroma', 'background', 'cancer-associated stroma', 'normal colon mucosa', 'smooth muscle', 'background', 'smooth muscle', 'cancer-associated stroma', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'smooth muscle', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'smooth muscle', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'cancer-associated stroma', 'adipose', 'cancer-associated stroma', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'adipose', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'background', 'background', 'adipose', 'background', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'smooth muscle', 'background', 'cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'lymphocytes', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'normal colon mucosa', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium']
# Correct Classes: ['cancer-associated stroma', 'debris', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'debris', 'smooth muscle', 'cancer-associated stroma', 'debris', 'background', 'adipose', 'smooth muscle', 'mucus', 'debris', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'lymphocytes', 'adipose', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'smooth muscle', 'mucus', 'lymphocytes', 'mucus', 'adipose', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'mucus', 'mucus', 'normal colon mucosa', 'mucus', 'adipose', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'background', 'lymphocytes', 'background', 'normal colon mucosa', 'adipose', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'debris', 'background', 'smooth muscle', 'background', 'mucus', 'debris', 'cancer-associated stroma', 'adipose', 'normal colon mucosa', 'smooth muscle', 'smooth muscle', 'adipose', 'adipose', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'debris', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'smooth muscle', 'background', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'debris', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'lymphocytes', 'mucus', 'debris', 'smooth muscle', 'normal colon mucosa', 'background', 'adipose', 'background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium']
# Accuracy: 30 out of 100

# %%
x_sam = pd.DataFrame(exp_results)

# %%
x_sam
# Out:
#    experiment  number of classes   model_name model_type        accuracy  \
# 0           0                  5       gpt-4o     openai  148 out of 200
# 1           0                  3       gpt-4o     openai  114 out of 200
# 2           0                  2       gpt-4o     openai   95 out of 200
# 3           0                  1       gpt-4o     openai   40 out of 100
# 4           0                  5  gpt-4o-mini     openai  131 out of 200
# 5           0                  3  gpt-4o-mini     openai  101 out of 200
# 6           0                  2  gpt-4o-mini     openai   82 out of 200
# 7           0                  1  gpt-4o-mini     openai   30 out of 100
#
#                                          image_paths  \
# 0  [../Datasets/PathMNIST/test\7\image_2935.png, ...
# 1  [../Datasets/PathMNIST/test\7\image_2935.png, ...
# 2  [../Datasets/PathMNIST/test\7\image_2935.png, ...
# 3  [../Datasets/PathMNIST/test\7\image_2935.png, ...
# 4  [../Datasets/PathMNIST/test\7\image_3832.png, ...
# 5  [../Datasets/PathMNIST/test\8\image_1288.png, ...
# 6  [../Datasets/PathMNIST/test\8\image_1288.png, ...
# 7  [../Datasets/PathMNIST/test\7\image_3832.png, ...
#
#                                LLM Predicted Classes  \
# 0  [[normal colon mucosa, background, smooth musc...
# 1  [[background, smooth muscle, cancer-associated...
# 2  [[cancer-associated stroma, smooth muscle], [b...
# 3  [cancer-associated stroma, cancer-associated s...
# 4  [[cancer-associated stroma, normal colon mucos...
# 5  [[background, colorectal adenocarcinoma epithe...
# 6  [[cancer-associated stroma, colorectal adenoca...
# 7  [cancer-associated stroma, debris, mucus, canc...
#
#                                      Correct Classes  \
# 0  [cancer-associated stroma, smooth muscle, smoo...
# 1  [cancer-associated stroma, smooth muscle, smoo...
# 2  [cancer-associated stroma, smooth muscle, smoo...
# 3  [cancer-associated stroma, smooth muscle, smoo...
# 4  [cancer-associated stroma, debris, normal colo...
# 5  [colorectal adenocarcinoma epithelium, colorec...
# 6  [colorectal adenocarcinoma epithelium, colorec...
# 7  [cancer-associated stroma, debris, normal colo...
#
#                                        Voting Result
# 0                                               None
# 1                                               None
# 2                                               None
# 3  [[cancer-associated stroma, smooth muscle, bac...
# 4                                               None
# 5                                               None
# 6                                               None
# 7  [[normal colon mucosa, cancer-associated strom...

# %%
pd.DataFrame(exp_results).to_csv(f"{DATASET_NAME}_results_Algorithm4_EXP1.csv", index=False)
