# %% [markdown]
# #### This code serves to test Algorithm 1 for the Iterative Domain Information Framework

# %%
import glob as glob
import math, random
import pandas as pd
from DatasetNames import get_dataset_class_name
from ExtraFunctions import *
from MultiClassPrediction import MultiClassPrediction, MultiClassImageTask
from SingleClassPrediction import SingleClassPrediction

# %%
DATASET_NAME = "PathMNIST"
NUMBER_OF_IMAGES = 100 # Total number of images to be used

source_directory = f"../Datasets/{DATASET_NAME}/test"  # Change this to your test directory path
_, image_paths = get_balanced_random_images(source_directory, n = NUMBER_OF_IMAGES)

random.seed(55)
random.shuffle(image_paths)
initial_image_paths = image_paths.copy()

dataset_classes_of_interest = get_dataset_class_name(DATASET_NAME)
init_classes_of_interest = list(dataset_classes_of_interest.values())

classes_of_interest_list = [random.sample(init_classes_of_interest, len(init_classes_of_interest))] * len(image_paths)

# %% [markdown]
# #### Playground

# %%
number_of_experiment = 1

model_list = [
    {
        "model_name": "gpt-4o",
        "model_type": "openai",
    },
    {
        "model_name": "gpt-4o-mini",
        "model_type": "openai",
    }
]

# %%
mcp = MultiClassPrediction(batch_size = 1, max_workers=2)
scp = SingleClassPrediction(batch_size = 1, max_workers=2)

exp_results = []

# Iterate over the number of experiments
for experiment in range(number_of_experiment):
    print(f"Experiment {experiment+1}/{number_of_experiment}")

    # Iterate over the models
    for model in model_list:
        model_name = model["model_name"]
        model_type = model["model_type"]

        print(f"Model: {model_name}")
        print(f"Model Type: {model_type}")

        # Update the model
        mcp.update_model(model_name)
        scp.update_model(model_name)

        # For each model, initialize the variables for the Algorithm
        n = len(init_classes_of_interest)
        k = 2
        threshold = 2
        number_of_classes_to_predict = math.ceil(n / k)
        image_paths = initial_image_paths
        classes_of_interest_list = [random.sample(init_classes_of_interest, len(init_classes_of_interest))] * len(image_paths)

        while number_of_classes_to_predict >= threshold:

            # Create the multiclass image tasks
            multiclass_image_tasks = create_multiclass_augmented_image_tasks(image_paths, classes_of_interest_list, number_of_classes_to_predict=number_of_classes_to_predict)

            # Prompt the model to predict "number_of_classes_to_predict" classes for each image
            rs = mcp.process_images(multiclass_image_tasks, model_type)

            # Set the predicted classes as the new classes of interest
            result_list, image_paths, classes_of_interest_list = extract_image_classes_from_multiclass_predictions(rs, number_of_classes_to_predict)
            
            image_paths_classes = [dataset_classes_of_interest[image_path.split("\\")[-2]] for image_path in image_paths]
            curr_pred_acc = compute_top_n_accuracy(image_paths_classes, classes_of_interest_list)

            # print(f"Predicted Classes: {classes_of_interest_list}")
            # print(f"Correct Classes: {image_paths_classes}")
            print(f"Accuracy: {curr_pred_acc}")

            log_experiment_results(dataset_classes_of_interest, exp_results, experiment, model_name, model_type, number_of_classes_to_predict, image_paths, classes_of_interest_list)

            # Update the number of classes to predict
            number_of_classes_to_predict = math.ceil(number_of_classes_to_predict / k)

        if rs:
            # Result from Multiclass Prediction
            result_list, _, _ = extract_image_classes_from_multiclass_predictions(rs)
        else:
            # Go to SingleTask result list directly
            result_list = create_singleclass_image_tasks(image_paths, classes_of_interest_list)

        # Predict the single classes for each image
        f_res = scp.process_images(result_list, model_type)
        correct_classes, pred_classes, image_paths = extract_single_classes(f_res, dataset_classes_of_interest)

        # Count the number of matches
        pred_result = count_matches(correct_classes, pred_classes)

        # print(f"Predicted Classes: {pred_classes}")
        # print(f"Correct Classes: {correct_classes}")
        print(f"Accuracy: {pred_result}")

        log_experiment_results(dataset_classes_of_interest, exp_results, experiment, model_name, model_type, number_of_classes_to_predict, image_paths, pred_classes)
# Out:
# Experiment 1/1
# Model: gpt-4o
# Model Type: openai
# Accuracy: 78 out of 100
# Predicted Classes of Interest: [['debris', 'mucus', 'background', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'mucus', 'debris', 'lymphocytes'], ['lymphocytes', 'background', 'cancer-associated stroma', 'smooth muscle', 'debris'], ['background', 'debris', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'background'], ['colorectal adenocarcinoma epithelium', 'mucus', 'lymphocytes', 'background', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris', 'background', 'mucus', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma', 'lymphocytes', 'background', 'colorectal adenocarcinoma epithelium'], ['debris', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'background'], ['smooth muscle', 'debris', 'background', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'smooth muscle', 'mucus', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'mucus', 'normal colon mucosa', 'background', 'lymphocytes'], ['smooth muscle', 'lymphocytes', 'background', 'mucus', 'adipose'], ['mucus', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'normal colon mucosa'], ['lymphocytes', 'cancer-associated stroma', 'debris', 'smooth muscle', 'background'], ['normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus', 'debris', 'cancer-associated stroma'], ['lymphocytes', 'smooth muscle', 'debris', 'cancer-associated stroma', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'mucus', 'smooth muscle', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'mucus'], ['background', 'smooth muscle', 'cancer-associated stroma', 'lymphocytes', 'normal colon mucosa'], ['debris', 'mucus', 'smooth muscle', 'background', 'lymphocytes'], ['normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle'], ['mucus', 'cancer-associated stroma', 'background', 'lymphocytes', 'debris'], ['debris', 'smooth muscle', 'background', 'lymphocytes', 'cancer-associated stroma'], ['mucus', 'smooth muscle', 'debris', 'background', 'adipose'], ['lymphocytes', 'background', 'adipose', 'smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'background', 'mucus'], ['background', 'cancer-associated stroma', 'debris', 'mucus', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'background', 'lymphocytes', 'cancer-associated stroma'], ['mucus', 'lymphocytes', 'normal colon mucosa', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['debris', 'lymphocytes', 'smooth muscle', 'background', 'mucus'], ['debris', 'lymphocytes', 'smooth muscle', 'mucus', 'background'], ['cancer-associated stroma', 'lymphocytes', 'background', 'smooth muscle', 'debris'], ['mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'debris'], ['adipose', 'debris', 'smooth muscle', 'lymphocytes', 'background'], ['debris', 'cancer-associated stroma', 'mucus', 'background', 'lymphocytes'], ['background', 'normal colon mucosa', 'adipose', 'debris', 'mucus'], ['lymphocytes', 'mucus', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'normal colon mucosa'], ['lymphocytes', 'mucus', 'normal colon mucosa', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'mucus', 'cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'smooth muscle', 'debris', 'background', 'adipose'], ['cancer-associated str ...
# Correct Classes: ['background', 'debris', 'cancer-associated stroma', 'lymphocytes', 'smooth muscle', 'debris', 'lymphocytes', 'debris', 'mucus', 'cancer-associated stroma', 'mucus', 'normal colon mucosa', 'adipose', 'mucus', 'cancer-associated stroma', 'adipose', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'background', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'adipose', 'mucus', 'mucus', 'debris', 'lymphocytes', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'smooth muscle', 'debris', 'background', 'background', 'adipose', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'debris', 'adipose', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'adipose', 'normal colon mucosa', 'lymphocytes', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'adipose', 'normal colon mucosa', 'lymphocytes', 'lymphocytes', 'mucus', 'normal colon mucosa', 'smooth muscle', 'smooth muscle', 'background', 'cancer-associated stroma', 'debris', 'background', 'adipose', 'debris', 'smooth muscle', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'adipose', 'background', 'debris', 'cancer-associated stroma', 'mucus', 'debris', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'adipose', 'lymphocytes', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'normal colon mucosa', 'normal colon mucosa', 'debris']
# Accuracy: 78 out of 100
# Accuracy: 63 out of 100
# Predicted Classes of Interest: [['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['debris', 'background', 'lymphocytes'], ['smooth muscle', 'lymphocytes', 'cancer-associated stroma'], ['smooth muscle', 'background', 'cancer-associated stroma'], ['background', 'adipose', 'debris'], ['smooth muscle', 'cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['cancer-associated stroma', 'background', 'smooth muscle'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['adipose', 'debris', 'background'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa'], ['normal colon mucosa', 'lymphocytes', 'smooth muscle'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'background', 'cancer-associated stroma'], ['adipose', 'smooth muscle', 'background'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'debris', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'smooth muscle', 'cancer-associated stroma'], ['smooth muscle', 'debris', 'background'], ['colorectal adenocarcinoma epithelium', 'smooth muscle', 'cancer-associated stroma'], ['smooth muscle', 'normal colon mucosa', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['debris', 'background', 'lymphocytes'], ['normal colon mucosa', 'lymphocytes', 'smooth muscle'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['lymphocytes', 'background', 'cancer-associated stroma'], ['debris', 'adipose', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'smooth muscle', 'debris'], ['lymphocytes', 'smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['smooth muscle', 'lymphocytes', 'cancer-associated stroma'], ['smooth muscle', 'cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['cancer-associated stroma', 'background', 'smooth muscle'], ['smooth muscle', 'colorectal adenocarcinoma epithelium', 'background'], ['smooth muscle', 'background', 'debris'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'lymphocytes', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'debris', 'smooth muscle'], ['mucus', 'lymphocytes', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma', 'smooth muscle'], ['debris', 'background', 'lymphocytes'], ['lymphocytes', 'debris', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'smooth muscle', 'cancer-associated stroma'], ['background', 'lymphocytes', 'smooth muscle'], ['debris', 'lymphocytes', 'background'], ['background', 'debris', 'lymphocytes'], ['mucus', 'lymphocytes', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'smooth muscle', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes', 'debris'], ['background', 'lymphocytes', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'normal colon mucosa'], ['smooth muscle', 'lymphocytes', 'normal colon mucosa'], ['adipose', 'smooth muscle', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes'], ['lymphocytes',  ...
# Correct Classes: ['debris', 'background', 'cancer-associated stroma', 'smooth muscle', 'adipose', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'mucus', 'lymphocytes', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'normal colon mucosa', 'smooth muscle', 'adipose', 'mucus', 'normal colon mucosa', 'background', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'background', 'mucus', 'smooth muscle', 'debris', 'background', 'background', 'lymphocytes', 'lymphocytes', 'adipose', 'normal colon mucosa', 'background', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'cancer-associated stroma', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'adipose', 'lymphocytes', 'smooth muscle', 'debris', 'adipose', 'mucus', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'lymphocytes', 'smooth muscle', 'background', 'lymphocytes', 'mucus', 'adipose', 'normal colon mucosa', 'cancer-associated stroma', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'cancer-associated stroma', 'debris', 'background', 'mucus', 'colorectal adenocarcinoma epithelium', 'adipose', 'adipose', 'normal colon mucosa', 'adipose', 'mucus', 'cancer-associated stroma', 'mucus', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'debris', 'background', 'adipose', 'debris', 'cancer-associated stroma', 'mucus', 'cancer-associated stroma', 'debris', 'debris', 'mucus', 'debris', 'smooth muscle', 'debris', 'adipose', 'normal colon mucosa', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'cancer-associated stroma']
# Accuracy: 63 out of 100
# Accuracy: 61 out of 100
# Predicted Classes of Interest: [['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'lymphocytes'], ['background', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'debris'], ['smooth muscle', 'background'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['smooth muscle', 'adipose'], ['lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes'], ['adipose', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'adipose'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'lymphocytes'], ['debris', 'background'], ['cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['debris', 'background'], ['adipose', 'lymphocytes'], ['lymphocytes', 'background'], ['cancer-associated stroma', 'lymphocytes'], ['smooth muscle', 'background'], ['lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['adipose', 'background'], ['smooth muscle', 'normal colon mucosa'], ['debris', 'background'], ['smooth muscle', 'background'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'lymphocytes'], ['lymphocytes', 'normal colon mucosa'], ['mucus', 'debris'], ['cancer-associated stroma', 'smooth muscle'], ['debris', 'background'], ['cancer-associated stroma', 'smooth muscle'], ['debris', 'background'], ['smooth muscle', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma'], ['background', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'smooth muscle'], ['smooth muscle', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['background', 'debris'], ['cancer-associated stroma', 'lymphocytes'], ['smooth muscle', 'debris'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'smooth muscle'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'smooth muscle'], ['cancer-associated stroma', 'smooth muscle'], ['background', 'debris'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'background'], ['lymphocytes', 'debris'], ['smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['cancer-associated stroma', 'smooth muscle'], ['smooth muscle', 'background'], ['adipose', 'background'], ['smooth muscle', 'debris'], ['lymphocytes', 'normal colon mucosa'], ['cancer-associated stroma', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'smooth muscle'], ['background', 'adipose'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['adipose', 'd ...
# Correct Classes: ['mucus', 'cancer-associated stroma', 'debris', 'smooth muscle', 'background', 'colorectal adenocarcinoma epithelium', 'adipose', 'background', 'colorectal adenocarcinoma epithelium', 'mucus', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'adipose', 'debris', 'cancer-associated stroma', 'mucus', 'debris', 'background', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'lymphocytes', 'lymphocytes', 'smooth muscle', 'lymphocytes', 'debris', 'adipose', 'normal colon mucosa', 'background', 'adipose', 'colorectal adenocarcinoma epithelium', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'background', 'mucus', 'background', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'mucus', 'smooth muscle', 'smooth muscle', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'lymphocytes', 'background', 'debris', 'mucus', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'debris', 'normal colon mucosa', 'normal colon mucosa', 'debris', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'adipose', 'debris', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'smooth muscle', 'adipose', 'normal colon mucosa', 'adipose', 'adipose', 'lymphocytes', 'mucus', 'mucus', 'debris', 'smooth muscle', 'lymphocytes', 'smooth muscle', 'normal colon mucosa', 'adipose', 'cancer-associated stroma']
# Accuracy: 61 out of 100
# Accuracy: 48 out of 100
# Predicted Classes of Interest: ['smooth muscle', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'smooth muscle', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'adipose', 'cancer-associated stroma', 'cancer-associated stroma', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'background', 'colorectal adenocarcinoma epithelium', 'debris', 'adipose', 'lymphocytes', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'adipose', 'normal colon mucosa', 'background', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'debris', 'normal colon mucosa', 'smooth muscle', 'background', 'smooth muscle', 'debris', 'lymphocytes', 'lymphocytes', 'lymphocytes', 'lymphocytes', 'lymphocytes', 'smooth muscle', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'debris', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'smooth muscle', 'lymphocytes', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'background', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'adipose', 'smooth muscle', 'lymphocytes', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'smooth muscle', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'adipose', 'cancer-associated stroma']
# Correct Classes: ['mucus', 'cancer-associated stroma', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'background', 'background', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'adipose', 'debris', 'cancer-associated stroma', 'mucus', 'debris', 'lymphocytes', 'background', 'colorectal adenocarcinoma epithelium', 'background', 'adipose', 'lymphocytes', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'debris', 'adipose', 'normal colon mucosa', 'background', 'adipose', 'colorectal adenocarcinoma epithelium', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'adipose', 'normal colon mucosa', 'cancer-associated stroma', 'background', 'mucus', 'background', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'mucus', 'smooth muscle', 'smooth muscle', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'background', 'debris', 'mucus', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'debris', 'normal colon mucosa', 'normal colon mucosa', 'debris', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'cancer-associated stroma', 'adipose', 'adipose', 'debris', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'smooth muscle', 'adipose', 'normal colon mucosa', 'adipose', 'adipose', 'lymphocytes', 'mucus', 'mucus', 'debris', 'smooth muscle', 'smooth muscle', 'lymphocytes', 'normal colon mucosa', 'adipose', 'cancer-associated stroma']
# Accuracy: 48 out of 100
# Model: gpt-4o-mini
# Model Type: openai
# Accuracy: 83 out of 100
# Predicted Classes of Interest: [['lymphocytes', 'mucus', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'smooth muscle'], ['background', 'mucus', 'adipose', 'debris', 'smooth muscle'], ['lymphocytes', 'normal colon mucosa', 'debris', 'mucus', 'cancer-associated stroma'], ['mucus', 'smooth muscle', 'lymphocytes', 'debris', 'background'], ['normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'mucus'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus', 'debris'], ['normal colon mucosa', 'cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'mucus'], ['debris', 'background', 'adipose', 'mucus', 'lymphocytes'], ['lymphocytes', 'normal colon mucosa', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma', 'background', 'debris', 'mucus'], ['mucus', 'lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa'], ['cancer-associated stroma', 'smooth muscle', 'debris', 'lymphocytes', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'normal colon mucosa', 'mucus'], ['smooth muscle', 'mucus', 'background', 'cancer-associated stroma', 'debris'], ['mucus', 'lymphocytes', 'smooth muscle', 'background', 'debris'], ['lymphocytes', 'cancer-associated stroma', 'mucus', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'mucus', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes'], ['smooth muscle', 'debris', 'mucus', 'lymphocytes', 'cancer-associated stroma'], ['debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma'], ['mucus', 'lymphocytes', 'debris', 'smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus'], ['normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus', 'lymphocytes', 'cancer-associated stroma'], ['smooth muscle', 'adipose', 'debris', 'lymphocytes', 'background'], ['smooth muscle', 'debris', 'mucus', 'cancer-associated stroma', 'background'], ['debris', 'smooth muscle', 'background', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'lymphocytes', 'mucus', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium'], ['mucus', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma'], ['debris', 'smooth muscle', 'background', 'mucus', 'cancer-associated stroma'], ['debris', 'adipose', 'mucus', 'background', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'normal colon mucosa', 'mucus', 'cancer-associated stroma'], ['cancer-associated stroma', 'lymphocytes', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'mucus'], ['debris', 'lymphocytes', 'background', 'smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus', 'normal colon mucosa'], ['lymphocytes', 'debris', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus'], ['colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'mucus', 'lymphocytes', 'cancer-associated stroma'], ['debris', 'normal colon mucosa', 'background', 'mucus', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'mucus', 'normal colon mucosa', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'mucus', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['mucus', 'normal colon mucosa', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['lymphocytes', 'smooth muscle ...
# Correct Classes: ['adipose', 'adipose', 'background', 'mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'background', 'background', 'mucus', 'debris', 'smooth muscle', 'debris', 'mucus', 'adipose', 'normal colon mucosa', 'debris', 'smooth muscle', 'cancer-associated stroma', 'cancer-associated stroma', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'smooth muscle', 'mucus', 'background', 'normal colon mucosa', 'normal colon mucosa', 'cancer-associated stroma', 'normal colon mucosa', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'background', 'normal colon mucosa', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'cancer-associated stroma', 'debris', 'debris', 'adipose', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'background', 'cancer-associated stroma', 'mucus', 'background', 'debris', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'debris', 'adipose', 'debris', 'debris', 'adipose', 'adipose', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'adipose', 'adipose', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'lymphocytes', 'background', 'lymphocytes', 'smooth muscle', 'adipose', 'debris', 'background', 'normal colon mucosa', 'mucus', 'adipose', 'debris', 'cancer-associated stroma', 'mucus', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'normal colon mucosa', 'cancer-associated stroma', 'normal colon mucosa']
# Accuracy: 83 out of 100
# Accuracy: 56 out of 100
# Predicted Classes of Interest: [['smooth muscle', 'debris', 'mucus'], ['smooth muscle', 'background', 'normal colon mucosa'], ['debris', 'normal colon mucosa', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes', 'smooth muscle'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'debris', 'lymphocytes'], ['smooth muscle', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['mucus', 'cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'mucus', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'smooth muscle', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'smooth muscle', 'background'], ['debris', 'lymphocytes', 'adipose'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes', 'smooth muscle'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['background', 'debris', 'smooth muscle'], ['debris', 'lymphocytes', 'mucus'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'mucus'], ['cancer-associated stroma', 'debris', 'lymphocytes'], ['mucus', 'debris', 'lymphocytes'], ['mucus', 'debris', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma'], ['lymphocytes', 'normal colon mucosa', 'mucus'], ['cancer-associated stroma', 'lymphocytes', 'colorectal adenocarcinoma epithelium'], ['normal colon mucosa', 'lymphocytes', 'mucus'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['debris', 'mucus', 'smooth muscle'], ['cancer-associated stroma', 'mucus', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['lymphocytes', 'normal colon mucosa', 'mucus'], ['smooth muscle', 'debris', 'cancer-associated stroma'], ['smooth muscle', 'debris', 'background'], ['smooth muscle', 'debris', 'background'], ['smooth muscle', 'mucus', 'lymphocytes'], ['smooth muscle', 'lymphocytes', 'debris'], ['cancer-associated stroma', 'smooth muscle', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'lymphocytes', 'debris'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['adipose', 'debris', 'smooth muscle'], ['cancer-associated stroma', 'lymphocytes', 'smooth muscle'], ['smooth muscle', 'lymphocytes', 'cancer-associated stroma'], ['background', 'mucus', 'debris'], ['cancer-associated stroma', 'lymphocytes', 'debris'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['mucus', 'lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'mucus', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'debris', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['mucus', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['debris', 'smooth muscle', 'background'], ['lymphocytes', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma', 'debris'], ['lymphocytes', 'smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'debris', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma', 'color ...
# Correct Classes: ['adipose', 'normal colon mucosa', 'background', 'smooth muscle', 'normal colon mucosa', 'smooth muscle', 'smooth muscle', 'debris', 'background', 'smooth muscle', 'lymphocytes', 'smooth muscle', 'adipose', 'debris', 'normal colon mucosa', 'cancer-associated stroma', 'cancer-associated stroma', 'debris', 'debris', 'lymphocytes', 'adipose', 'lymphocytes', 'mucus', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'adipose', 'background', 'debris', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'adipose', 'mucus', 'colorectal adenocarcinoma epithelium', 'background', 'mucus', 'smooth muscle', 'mucus', 'adipose', 'adipose', 'cancer-associated stroma', 'debris', 'lymphocytes', 'adipose', 'smooth muscle', 'smooth muscle', 'background', 'lymphocytes', 'normal colon mucosa', 'debris', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'background', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'cancer-associated stroma', 'cancer-associated stroma', 'normal colon mucosa', 'smooth muscle', 'debris', 'lymphocytes', 'mucus', 'mucus', 'background', 'smooth muscle', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'mucus', 'debris', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium', 'normal colon mucosa', 'lymphocytes', 'mucus', 'mucus', 'background', 'normal colon mucosa', 'cancer-associated stroma', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'adipose', 'adipose', 'normal colon mucosa', 'background', 'lymphocytes', 'background', 'lymphocytes', 'cancer-associated stroma', 'normal colon mucosa', 'lymphocytes']
# Accuracy: 56 out of 100
# Accuracy: 52 out of 100
# Predicted Classes of Interest: [['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'mucus'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'background'], ['cancer-associated stroma', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['background', 'smooth muscle'], ['debris', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'mucus'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['lymphocytes', 'cancer-associated stroma'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma'], ['debris', 'lymphocytes'], ['mucus', 'smooth muscle'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma'], ['lymphocytes', 'cancer-associated stroma'], ['mucus', 'lymphocytes'], ['lymphocytes', 'background'], ['lymphocytes', 'mucus'], ['background', 'smooth muscle'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes'], ['background', 'smooth muscle'], ['background', 'smooth muscle'], ['debris', 'smooth muscle'], ['background', 'adipose'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'smooth muscle'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'adipose'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['mucus', 'normal colon mucosa'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'adipose'], ['colorectal adenocarcinoma epithelium', 'debris'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['adipose', 'debris'], ['colorectal adenocarcinoma epithelium', 'mucus'], ['lymphocytes', 'mucus'], ['lymphocytes', 'cancer-associated stroma'], ['mucus', 'lymphocytes'], ['debris', 'smooth muscle'], ['smooth muscle', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['cancer-associated stroma', 'lymphocytes'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['smooth muscle', 'lymphocytes'], ['cancer-associated stroma', 'lymphocytes'], ['normal colon mucosa', 'smooth muscle'], ['mucus', 'lymphocytes'], ['debris', 'smooth muscle'], ['lymphocytes', 'cancer-associated stroma'], ['normal colon mucosa', 'lymphocytes'], ['smooth muscle', 'cancer-associated stroma'], ['smooth muscle', 'background'], ['colorectal adenocarcinoma epithelium', 'cancer-associated stroma'], ['colorectal adenocarcinoma epithelium', 'lymphocytes'], ['mucus', 'smooth muscle'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-associated stroma', 'lymphocytes'], ['lymphocytes', 'colorectal adenocarcinoma epithelium'], ['mucus', 'background'], ['cancer-associated stroma', 'colorectal adenocarcinoma epithelium'], ['smooth muscle', 'cancer-associated stroma'], ['cancer-as ...
# Correct Classes: ['lymphocytes', 'cancer-associated stroma', 'background', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'debris', 'mucus', 'adipose', 'cancer-associated stroma', 'background', 'normal colon mucosa', 'smooth muscle', 'normal colon mucosa', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background', 'cancer-associated stroma', 'adipose', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'adipose', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'debris', 'adipose', 'background', 'background', 'mucus', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'mucus', 'adipose', 'adipose', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'normal colon mucosa', 'adipose', 'debris', 'cancer-associated stroma', 'normal colon mucosa', 'debris', 'debris', 'normal colon mucosa', 'adipose', 'debris', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'lymphocytes', 'adipose', 'background', 'debris', 'lymphocytes', 'normal colon mucosa', 'mucus', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'normal colon mucosa', 'background', 'adipose', 'lymphocytes', 'background', 'mucus', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'smooth muscle', 'lymphocytes', 'background', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'mucus', 'smooth muscle', 'debris', 'adipose', 'cancer-associated stroma', 'smooth muscle', 'background', 'smooth muscle', 'normal colon mucosa', 'mucus', 'background', 'mucus', 'normal colon mucosa', 'lymphocytes', 'mucus']
# Accuracy: 52 out of 100
# Accuracy: 36 out of 100
# Predicted Classes of Interest: ['cancer-associated stroma', 'mucus', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'lymphocytes', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'mucus', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'mucus', 'cancer-associated stroma', 'lymphocytes', 'background', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'debris', 'adipose', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'adipose', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'adipose', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'cancer-associated stroma', 'adipose', 'mucus', 'lymphocytes', 'lymphocytes', 'mucus', 'smooth muscle', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'cancer-associated stroma', 'smooth muscle', 'mucus', 'lymphocytes', 'smooth muscle', 'cancer-associated stroma', 'normal colon mucosa', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'mucus', 'cancer-associated stroma', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'background', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'lymphocytes', 'lymphocytes', 'cancer-associated stroma', 'smooth muscle', 'smooth muscle', 'lymphocytes', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'debris', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'debris', 'smooth muscle', 'mucus', 'colorectal adenocarcinoma epithelium', 'colorectal adenocarcinoma epithelium', 'lymphocytes']
# Correct Classes: ['cancer-associated stroma', 'background', 'lymphocytes', 'colorectal adenocarcinoma epithelium', 'debris', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'debris', 'mucus', 'adipose', 'background', 'cancer-associated stroma', 'normal colon mucosa', 'normal colon mucosa', 'smooth muscle', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'background', 'cancer-associated stroma', 'adipose', 'colorectal adenocarcinoma epithelium', 'lymphocytes', 'adipose', 'cancer-associated stroma', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'adipose', 'debris', 'background', 'background', 'mucus', 'lymphocytes', 'cancer-associated stroma', 'cancer-associated stroma', 'mucus', 'adipose', 'adipose', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'adipose', 'normal colon mucosa', 'debris', 'cancer-associated stroma', 'normal colon mucosa', 'debris', 'debris', 'normal colon mucosa', 'adipose', 'colorectal adenocarcinoma epithelium', 'debris', 'lymphocytes', 'lymphocytes', 'adipose', 'background', 'debris', 'lymphocytes', 'normal colon mucosa', 'mucus', 'smooth muscle', 'debris', 'colorectal adenocarcinoma epithelium', 'mucus', 'colorectal adenocarcinoma epithelium', 'debris', 'colorectal adenocarcinoma epithelium', 'smooth muscle', 'mucus', 'normal colon mucosa', 'background', 'lymphocytes', 'adipose', 'mucus', 'background', 'smooth muscle', 'normal colon mucosa', 'normal colon mucosa', 'adipose', 'cancer-associated stroma', 'smooth muscle', 'lymphocytes', 'background', 'colorectal adenocarcinoma epithelium', 'cancer-associated stroma', 'lymphocytes', 'lymphocytes', 'mucus', 'smooth muscle', 'adipose', 'debris', 'cancer-associated stroma', 'smooth muscle', 'background', 'smooth muscle', 'normal colon mucosa', 'background', 'mucus', 'mucus', 'normal colon mucosa', 'lymphocytes', 'mucus']
# Accuracy: 36 out of 100

# %%
x_sam = pd.DataFrame(exp_results)

# %%
x_sam
# Out:
#    experiment  number of classes   model_name model_type       accuracy  \
# 0           0                  5       gpt-4o     openai  78 out of 100
# 1           0                  3       gpt-4o     openai  63 out of 100
# 2           0                  2       gpt-4o     openai  61 out of 100
# 3           0                  1       gpt-4o     openai  48 out of 100
# 4           0                  5  gpt-4o-mini     openai  83 out of 100
# 5           0                  3  gpt-4o-mini     openai  56 out of 100
# 6           0                  2  gpt-4o-mini     openai  52 out of 100
# 7           0                  1  gpt-4o-mini     openai  36 out of 100
#
#                                          image_paths  \
# 0  [../Datasets/PathMNIST/test\1\image_5521.png, ...
# 1  [../Datasets/PathMNIST/test\2\image_6417.png, ...
# 2  [../Datasets/PathMNIST/test\4\image_1905.png, ...
# 3  [../Datasets/PathMNIST/test\4\image_1905.png, ...
# 4  [../Datasets/PathMNIST/test\0\image_3756.png, ...
# 5  [../Datasets/PathMNIST/test\0\image_2150.png, ...
# 6  [../Datasets/PathMNIST/test\3\image_3284.png, ...
# 7  [../Datasets/PathMNIST/test\7\image_4939.png, ...
#
#                                LLM Predicted Classes  \
# 0  [[cancer-associated stroma, debris, background...
# 1  [[cancer-associated stroma, colorectal adenoca...
# 2  [[smooth muscle, cancer-associated stroma], [c...
# 3  [smooth muscle, smooth muscle, colorectal aden...
# 4  [[mucus, lymphocytes, smooth muscle, colorecta...
# 5  [[debris, smooth muscle, mucus], [smooth muscl...
# 6  [[lymphocytes, colorectal adenocarcinoma epith...
# 7  [cancer-associated stroma, mucus, lymphocytes,...
#
#                                      Correct Classes Voting Result
# 0  [background, debris, cancer-associated stroma,...          None
# 1  [debris, background, cancer-associated stroma,...          None
# 2  [mucus, cancer-associated stroma, debris, smoo...          None
# 3  [mucus, cancer-associated stroma, debris, smoo...          None
# 4  [adipose, adipose, background, mucus, colorect...          None
# 5  [adipose, normal colon mucosa, background, smo...          None
# 6  [lymphocytes, cancer-associated stroma, backgr...          None
# 7  [cancer-associated stroma, background, lymphoc...          None

# %%
pd.DataFrame(exp_results).to_csv(f"{DATASET_NAME}_results_Algorithm1_EXP1_batch_size_1.csv", index=False)
